# %%
import pandas as pd
reviews = pd.read_csv("C:/Users/aliemir/Desktop/yazilim/Python/kaggle/Padas/Datafiles/winemag-data-130k-v2.csv", index_col = 0)
pd.set_option('max_rows', 5)

# %%
reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.rename(columns = {'points': 'score'}) # renaming column name of 'points'
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
index_rename = reviews.rename(index = {0: 'firstEntry', 1: 'secondEntry'})
index_rename.head()
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# 2                  US  Tart and snappy, the flavors of lime flesh and...
# 3                  US  Pineapple rind, lemon pith and orange blossom ...
# 4                  US  Much like the regular bottling from 2012, this...
#
#                                     designation  points  price  \
# firstEntry                         Vulkà Bianco      87    NaN
# secondEntry                            Avidagos      87   15.0
# 2                                           NaN      87   14.0
# 3                          Reserve Late Harvest      87   13.0
# 4            Vintner's Reserve Wild Child Block      87   65.0
#
#                       province             region_1           region_2  \
# firstEntry   Sicily & Sardinia                 Etna                NaN
# ...

# %%
canadian_youtube = pd.read_csv("C:/Users/aliemir/Desktop/yazilim/Python/kaggle/Padas/Datafiles/CAvideos.csv")
british_youtube = pd.read_csv("C:/Users/aliemir/Desktop/yazilim/Python/kaggle/Padas/Datafiles/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube]) #Attaching two different data frame together
# Out:
#             trending_date                                              title  \
# video_id
# n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
# 0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
# ...                   ...                                                ...
# -DRsfNObKIQ      18.14.06  Eleni Foureira - Fuego - Cyprus - LIVE - First...
# 4YFo4bdMO8Q      18.14.06  KYLE - Ikuyo feat.  2 Chainz & Sophia Black [A...
#
#                        channel_title  category_id              publish_time  \
# video_id
# n1WpP7iowLc               EminemVEVO           10  2017-11-10T17:00:03.000Z
# 0dBIkQ4Mz1M                iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ...                              ...          ...                       ...
# -DRsfNObKIQ  Eurovision Song Contest           24  2018-05-08T20:32:32.000Z
# 4YFo4bdMO8Q           SuperDuperKyle           10  2018-05-11T04:06:35.000Z
#
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix = '_CAN', rsuffix = '_UK').head()
# Out:
#                                                                      channel_title_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                 Markiplier
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03             AlexRamiGaming
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03             AlexRamiGaming
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       Pure Living for Life
#                                                    17.21.12       Pure Living for Life
#
#                                                                   category_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                    20
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03                    20
# ...
